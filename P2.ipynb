# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned data (your format)
bollywood = pd.read_csv('cleaned_bollywood_movies.csv', index_col=0)
tollywood = pd.read_csv('cleaned_tollywood_movies.csv', index_col=0)
indian = pd.read_csv('cleaned_indian_movies.csv', index_col=0)

# Add industry labels
bollywood['Industry'] = 'Bollywood'
tollywood['Industry'] = 'Tollywood'
indian['Industry'] = 'Other'

# Combine all datasets
all_movies = pd.concat([bollywood, tollywood, indian], ignore_index=True)

# Plot BoxOffice distribution
plt.figure(figsize=(12, 6))
sns.boxplot(data=all_movies, x='Industry', y='BoxOffice (Crores)', palette='Set2')
plt.title('Box Office Collection Distribution by Industry')
plt.ylabel('BoxOffice (Crores)')
plt.grid(True)
plt.show()

# Identify Outliers using 90th percentile threshold
threshold = all_movies['BoxOffice (Crores)'].quantile(0.90)
outliers = all_movies[all_movies['BoxOffice (Crores)'] > threshold]

# Show outliers
print("\nTop BoxOffice Outliers (Above 90th Percentile):")
print(outliers[['Title', 'Industry', 'BoxOffice (Crores)']])
# Out:
# /tmp/ipykernel_30345/1562293446.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=all_movies, x='Industry', y='BoxOffice (Crores)', palette='Set2')
# Top BoxOffice Outliers (Above 90th Percentile):
#                           Title   Industry  BoxOffice (Crores)
# 3   Baahubali 2: The Conclusion  Bollywood              1810.0
# 6                        Dangal  Bollywood              2140.0
# 8                            PK  Bollywood               792.0
# 9                   2.0 (Tamil)  Bollywood               800.0
# 51  Baahubali 2: The Conclusion  Bollywood              1810.0
# 55  Baahubali 2: The Conclusion  Tollywood              1810.0
# 64  Baahubali 2: The Conclusion  Tollywood              1810.0
# 66                  2.0 (Tamil)      Other               800.0
